# %%
import numpy as np

# %%
x = np.array([5,4,1,9,10,11,13])
x
# Out:
# array([ 5,  4,  1,  9, 10, 11, 13])

# %%
idx = np.argsort(x)
idx
# Out:
# array([2, 1, 0, 3, 4, 5, 6], dtype=int64)

# %%
idx = idx[::-1]

# %%
idx
# Out:
# array([6, 5, 4, 3, 0, 1, 2], dtype=int64)

# %%
idx = idx[:3]
idx
# Out:
# array([6, 5, 4], dtype=int64)

# %%
shortened = x[idx]

# %%
shortened
# Out:
# array([13, 11, 10])
